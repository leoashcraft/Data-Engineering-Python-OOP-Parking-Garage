# %% [markdown]
# # Parking Garage Project
#
# Your assignment for today is to create a parking garage class to get more familiar with Object Oriented Programming(OOP).
#
# Your parking gargage class should have the following methods:
# - takeTicket
#    - This should decrease the amount of tickets available by 1
#    - This should decrease the amount of parkingSpaces available by 1
# - payForParking
#    - Display an input that waits for an amount from the user and store it in a variable
#    - If the payment variable is not empty then ->  display a message to the user that their ticket has been paid and they have 15mins to leave
#    - This should update the "currentTicket" dictionary key "paid" to True
# -leaveGarage
#    - If the ticket has been paid, display a message of "Thank You, have a nice day"
#    - If the ticket has not been paid, display an input prompt for payment
#       - Once paid, display message "Thank you, have a nice day!"
#    - Update parkingSpaces list to increase by 1
#    - Update tickets list to increase by 1
#
# You will need a few attributes as well:
# - tickets -> list
# - parkingSpaces -> list
# - currentTicket -> dictionary

# %%
from IPython.display import clear_output

class Garage():
    def __init__(self):
        self.tickets = 0
        self.spaces = 0
        self.parkingSpaces = [0, False, False, False, False, False]
        self.paymentStatus = {}
        self.currentTicket = {}
    # takeTicket
    # This should decrease the amount of tickets available by 1
    # This should decrease the amount of parkingSpaces available by 1
    def take_ticket(self):
        while self.tickets < 5:
            self.tickets += 1 # assigning ticket #
            self.parkingSpaces[self.tickets]= True
            self.currentTicket[self.tickets]="Unpaid"
            print(self.parkingSpaces)
            print(self.currentTicket)
            print(f"You're parked in spot #  {self.tickets}")
        else:
            print("Sorry, parking lot is full. Check back later.")
#         if self.tickets < 5:
#             self.tickets += 1 # assigning ticket #
        
    # payForParking
    # Display an input that waits for an amount from the user and store it in a variable
    # If the payment variable is not empty then -> display a message to the user that their 
    # ticket has been paid and they have 15mins to leave
    # This should update the "currentTicket" dictionary key "paid" to True
    def pay_for_parking(self):
        while self.tickets > 0:
            self.tickets -= 1 # assigning ticket #
            self.parkingSpaces[self.tickets]= False
            self.currentTicket[self.tickets]="paid"
            print(self.parkingSpaces)
            print(f"You're parked in spot #  {self.tickets}")
        else:
            print("The parking lot is now empty.")

        
        
        
    #leaveGarage
    # If the ticket has been paid, display a message of "Thank You, have a nice day"
    # If the ticket has not been paid, display an input prompt for payment
    # Once paid, display message "Thank you, have a nice day!"
    # Update parkingSpaces list to increase by 1
    # Update tickets list to increase by 1
    def leaveGarage(self):
        pass

# def getGarage():
#     while True:
#         response = input("\Welcome to the Parking Garage. Would you like to park now? (Yes/No)").lower().strip()
#         if response == "yes":
#             clear_output()

#         elif response == "no":
#             clear_output()

#             break
#         else:
#             clear_output()
#             print("\nYou've made an invalid selection, try again.")

# getGarage()
garagetest = Garage()
garagetest.take_ticket()
garagetest.pay_for_parking()
# Out:
# [0, True, False, False, False, False]
# {1: 'Unpaid'}
# You're parked in spot #  1
# [0, True, True, False, False, False]
# {1: 'Unpaid', 2: 'Unpaid'}
# You're parked in spot #  2
# [0, True, True, True, False, False]
# {1: 'Unpaid', 2: 'Unpaid', 3: 'Unpaid'}
# You're parked in spot #  3
# [0, True, True, True, True, False]
# {1: 'Unpaid', 2: 'Unpaid', 3: 'Unpaid', 4: 'Unpaid'}
# You're parked in spot #  4
# [0, True, True, True, True, True]
# {1: 'Unpaid', 2: 'Unpaid', 3: 'Unpaid', 4: 'Unpaid', 5: 'Unpaid'}
# You're parked in spot #  5
# Sorry, parking lot is full. Check back later.
# [0, True, True, True, False, True]
# You're parked in spot #  4
# [0, True, True, False, False, True]
# You're parked in spot #  3
# [0, True, False, False, False, True]
# You're parked in spot #  2
# [0, False, False, False, False, True]
# You're parked in spot #  1
# [False, False, False, False, False, True]
# You're parked in spot #  0
# The parking lot is now empty.
